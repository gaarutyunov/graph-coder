# %%
import torch

from graph_coder.train.train import train, setup_parser
from argparse import ArgumentParser
# Out:
# NOTE: Redirects are currently not supported in Windows or MacOs.

# %%
from argparse import Namespace, _StoreAction, _StoreTrueAction

parser = ArgumentParser()
setup_parser(parser)

args = {}

for action in parser._actions:
    if isinstance(action, (_StoreAction, _StoreTrueAction)):
        args[action.dest] = action.default

namespace = Namespace(**args)
namespace.data = "~/git-py"

# %%
train(namespace)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Users/germanarutunov/Library/Caches/pypoetry/virtualenvs/graph-coder-I0d2VrvT-py3.9/lib/python3.9/site-packages/pytorch_lightning/loops/utilities.py:89: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   rank_zero_warn(
#
#   | Name                     | Type                | Params
# -----------------------------------------------------------------
# 0 | graph_encoder            | TokenGTGraphEncoder | 77.7 M
# 1 | graph_decoder            | TokenGTGraphDecoder | 100 M
# 2 | masked_lm_pooler         | Linear              | 1.0 M
# 3 | lm_head_transform_weight | Linear              | 1.0 M
# 4 | activation_fn            | GELU                | 0
# 5 | layer_norm               | LayerNorm           | 2.0 K
# ...
